# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import rc
from matplotlib import font_manager
import pylab
import datetime



font_name = font_manager.FontProperties(fname = "/Library/Fonts/AppleGothic.ttf").get_name()
plt.rcParams["font.family"] = font_name
plt.rcParams['axes.unicode_minus'] = False

pd.set_option('display.max_columns',None)

# %%
m4 = pd.read_csv('./2개월모델/month4.csv')
m5 = pd.read_csv('./2개월모델/month5.csv')
m45 = pd.read_csv('./2개월모델/month45.csv')
m6 = pd.read_csv('./2개월모델/month6.csv')

m4 = m4.iloc[:,:-18]
m5 = m5.iloc[:,:-18]
m45 = m45.iloc[:,:-18]

# %%
m7 = pd.read_csv('./2개월모델/month7.csv')
m8 = pd.read_csv('./2개월모델/month8.csv')
m78 = pd.read_csv('./2개월모델/month78.csv')
m9 = pd.read_csv('./2개월모델/month9.csv')

m6 = m6.iloc[:,:-18]
m7 = m7.iloc[:,:-18]
m8 = m8.iloc[:,:-18]
m78 = m78.iloc[:,:-18]
m9 = m9.iloc[:,:-18]

# %%
m56 = pd.read_csv('./2개월모델/month56.csv')
m67 = pd.read_csv('./2개월모델/month67.csv')

m56 = m56.iloc[:,:-18]
m67 = m67.iloc[:,:-18]

# %%
data2 = pd.read_csv('podol_final2.csv')
data2 = data2.drop(columns='Unnamed: 0')
data2=data2.fillna(0)

# %%
M6 = data2[['CLAC3_NM','April','May','June']]

# %%
M6['April_May'] = M6['April'] + M6['May']
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
M6.columns = ['CLAC3_NM','M4','M5','M6','M45']

# %%
M6.head()
# Out:
#         CLAC3_NM       M4       M5       M6      M45
# 0           2단우산     66.0     44.0     46.0    110.0
# 1           3단우산    442.0    364.0    267.0    806.0
# 2  BB/파운데이션/컴팩트류  11386.0  13304.0  12012.0  24690.0
# 3          DIY가구     61.0    406.0    550.0    467.0
# 4          DIY완구      0.0      0.0      0.0      0.0

# %%
data = m4.merge(m5,on='CLAC3_NM',how='outer')
data = data.merge(m45,on='CLAC3_NM',how='outer')
data = data.merge(M6,on='CLAC3_NM',how='outer')

# %%
[i for i in range(1,17,3)]
# Out:
# [1, 4, 7, 10, 13, 16]

# %%
loca4=m4.iloc[:,-18:]
loca5=m4.iloc[:,-18:]
loca6=m4.iloc[:,-18:]

m4px = loca4.iloc[:,[0,3,6,9,12,15]]
m5px = loca5.iloc[:,[0,3,6,9,12,15]]
m45px = loca6.iloc[:,[0,3,6,9,12,15]]

m4min = loca4.iloc[:,[i for i in range(1,17,3)]]
m5min = loca5.iloc[:,[i for i in range(1,17,3)]]
m45min = loca6.iloc[:,[i for i in range(1,17,3)]]

m4max = loca4.iloc[:,[i for i in range(2,18,3)]]
m5max = loca5.iloc[:,[i for i in range(2,18,3)]]
m45max = loca6.iloc[:,[i for i in range(2,18,3)]]

# %%
m4px['m4px_mean'] = m4px.mean(axis=1)
m5px['m5px_mean'] = m5px.mean(axis=1)
m45px['m45px_mean'] = m45px.mean(axis=1)

m4min['m4min_mean'] = m4min.mean(axis=1)
m5min['m5min_mean'] = m5min.mean(axis=1)
m45min['m45min_mean'] = m45min.mean(axis=1)


m4max['m4max_mean'] = m4max.mean(axis=1)
m5max['m5max_mean'] = m5max.mean(axis=1)
m45max['m45max_mean'] = m45max.mean(axis=1)
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
weather = pd.read_csv('./날씨, 미세먼지 크롤링/weather.csv')

# %%
dust = pd.read_csv('./날씨, 미세먼지 크롤링/dust.csv')

# %%
weather['DATE'] = weather.DATE.apply(lambda x: datetime.datetime.strptime(str(x),'%Y%m%d'))
wpt = weather.DATE.dt
wpt_prop = pd.DataFrame({'year':wpt.year,
             'month':wpt.month,
             'day':wpt.day
             })
weather= pd.concat([weather,wpt_prop],axis=1)
weather.head()
# Out:
#        ZON_NM       DATE WEATHER  T_MAX  T_MIN  year  month  day
# 0  Gangwon-do 2018-03-01       비   -2.0    4.0  2018      3    1
# 1  Gangwon-do 2018-03-02    구름조금   -6.0    5.0  2018      3    2
# 2  Gangwon-do 2018-03-03    구름조금   -1.0   17.0  2018      3    3
# 3  Gangwon-do 2018-03-04       비    7.0   16.0  2018      3    4
# 4  Gangwon-do 2018-03-05  비/진눈개비    0.0    9.0  2018      3    5

# %%
dust['DATE'] = dust.DATE.apply(lambda x: datetime.datetime.strptime(str(x),'%Y%m%d'))
dpt = dust.DATE.dt
dpt_prop = pd.DataFrame({'year':dpt.year,
             'month':dpt.month,
             'day':dpt.day
             })
dust = pd.concat([dust,dpt_prop],axis=1)
dust.head()
# Out:
#        ZON_NM       DATE    px_mean  px_max  year  month  day
# 0  Gangwon-do 2018-03-01  26.695652      47  2018      3    1
# 1  Gangwon-do 2018-03-02  49.000000      63  2018      3    2
# 2  Gangwon-do 2018-03-03  44.000000      60  2018      3    3
# 3  Gangwon-do 2018-03-04  18.739130      43  2018      3    4
# 4  Gangwon-do 2018-03-05   9.863636      33  2018      3    5

# %%
weather['ZON_NM'].unique()
# Out:
# array(['Gangwon-do', 'Gyeonggi-do', 'Gyeongsangnam-do',
#        'Gyeongsangbuk-do', 'Gwangju', 'Daegu', 'Daejeon', 'Busan',
#        'Seoul', 'Ulsan', 'Incheon', 'Jeollanam-do', 'Jeollabuk-do',
#        'Jeju-do', 'Chungcheongnam-do', 'Chungcheongbuk-do', 'Sejong'],
#       dtype=object)

# %%
zonname = []
for i in dust['ZON_NM']:
    if (i =='Seoul') | (i =='Gyeonggi-do') | (i=='Incheon'):
        zonname.append('수도권')
    elif (i == 'Jeollabuk-do') | (i =='Jeollanam-do') | (i=='Gwangju'):
        zonname.append('전라도')
    elif (i =='Busan') | (i =='Ulsan') | (i=='Gyeongsangnam-do')| (i =='Gyeongsangbuk-do') | (i=='Daegu'):
        zonname.append('경상도')
    elif (i =='Chungcheongnam-do') | (i =='Chungcheongbuk-do') | (i=='Daejeon'):
        zonname.append('충청도')
    elif i =='Gangwon-do':
        zonname.append('강원도')
    elif i =='Jeju-do':
        zonname.append('제주도')
    elif i == 'Sejong':
        zonname.append('세종시')
dust['ZON_NM'] = zonname

# %%
zonname = []
for i in weather['ZON_NM']:
    if (i =='Seoul') | (i =='Gyeonggi-do') | (i=='Incheon'):
        zonname.append('수도권')
    elif (i == 'Jeollabuk-do') | (i =='Jeollanam-do') | (i=='Gwangju'):
        zonname.append('전라도')
    elif (i =='Busan') | (i =='Ulsan') | (i=='Gyeongsangnam-do')| (i =='Gyeongsangbuk-do') | (i=='Daegu'):
        zonname.append('경상도')
    elif (i =='Chungcheongnam-do') | (i =='Chungcheongbuk-do') | (i=='Daejeon'):
        zonname.append('충청도')
    elif i =='Gangwon-do':
        zonname.append('강원도')
    elif i =='Jeju-do':
        zonname.append('제주도')
    elif i == 'Sejong':
        zonname.append('세종시')
weather['ZON_NM'] = zonname

# %%
zon_list = weather['ZON_NM'].unique()

# %%
zon_list
# Out:
# array(['강원도', '수도권', '경상도', '전라도', '충청도', '제주도', '세종시'], dtype=object)

# %%
meanweather = weather.groupby(['ZON_NM','month']).mean()

# %%
meandust = dust.groupby(['ZON_NM','month']).mean()

# %%
meanweather.reset_index(inplace=True)

# %%
meandust.reset_index(inplace=True)

# %%
val = []
for month in range(4,8):
    for zonname in zon_list:
        q = 'ZON_NM == "'+ zonname + '" & (month == ' + str(month) +'| month == ' +str(month+1) +')'
        val.append(meanweather.query(q)[['T_MAX','T_MIN']].mean().to_frame().T)

# %%
dval = []
for month in range(4,8):
    for zonname in zon_list:
        q = 'ZON_NM == "'+ zonname + '" & (month == ' + str(month) +'| month == ' +str(month+1) +')'
        
        dval.append(meandust.query(q)[['px_mean']].mean().to_frame().T)

# %%
m4temp = pd.concat(val[:7],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']

m4temp.columns= ['M4_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]

# %%
m4dust
# Out:
#       px_mean   px_mean    px_mean    px_mean    px_mean   px_mean  px_mean
# 1   43.851703       NaN        NaN        NaN        NaN       NaN      NaN
# 9         NaN       NaN  48.686746        NaN        NaN       NaN      NaN
# 17        NaN  44.09113        NaN        NaN        NaN       NaN      NaN
# 25        NaN       NaN        NaN  41.861123        NaN       NaN      NaN
# 33        NaN       NaN        NaN        NaN        NaN  38.01282      NaN
# 41        NaN       NaN        NaN        NaN  45.696037       NaN      NaN

# %%
m4dust = pd.concat(val[:7],axis=1)

m4dust.columns= ['M4_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]

# %%
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)

# %%
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)

# %%
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))

# %%
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))

# %%
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)

# %%
fm4 = pd.concat([fm4,p4],axis=1)

# %%
fm4.to_csv('./2개월모델/m4_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[7:14],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M5_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm5 = pd.concat([m5,p4],axis=1)


m4dust = pd.concat(dval[7:14],axis=1)
m4dust.columns= ['M5_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm5 = pd.concat([fm5,p4],axis=1)

# %%
fm5.to_csv('./2개월모델/m5_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[14:21],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M6_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm6 = pd.concat([m6,p4],axis=1)


m4dust = pd.concat(dval[14:21],axis=1)
m4dust.columns= ['M6_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm6 = pd.concat([fm6,p4],axis=1)

# %%
fm6.to_csv('./2개월모델/m6_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[21:28],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M7_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm7 = pd.concat([m7,p4],axis=1)

m4dust = pd.concat(dval[21:28],axis=1)
m4dust.columns= ['M7_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm7 = pd.concat([fm7,p4],axis=1)

# %%
fm7.to_csv('./2개월모델/m7_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[28:35],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M8_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm8 = pd.concat([m8,p4],axis=1)


m4dust = pd.concat(dval[28:35],axis=1)
m4dust.columns= ['M8_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm8 = pd.concat([fm8,p4],axis=1)

# %%
fm8.to_csv('./2개월모델/m8_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[35:42],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M9_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm9 = pd.concat([m9,p4],axis=1)


m4dust = pd.concat(dval[35:42],axis=1)
m4dust.columns= ['M9_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm9 = pd.concat([fm9,p4],axis=1)

# %%
fm9.to_csv('./2개월모델/m9_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[0:7],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M45_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm45 = pd.concat([m45,p4],axis=1)


m4dust = pd.concat(dval[0:7],axis=1)
m4dust.columns= ['M45_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm45 = pd.concat([fm45,p4],axis=1)

# %%
fm45.to_csv('./2개월모델/m45_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[7:14],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M56_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm56 = pd.concat([m56,p4],axis=1)


m4dust = pd.concat(dval[7:14],axis=1)
m4dust.columns= ['M56_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm56 = pd.concat([fm56,p4],axis=1)

# %%
fm56.to_csv('./2개월모델/m56_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[14:21],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M67_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm67 = pd.concat([m67,p4],axis=1)


m4dust = pd.concat(dval[14:21],axis=1)
m4dust.columns= ['M67_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm67 = pd.concat([fm67,p4],axis=1)

# %%
fm67.to_csv('./2개월모델/m67_2.csv',index=False,index_label= False)

# %%
m4temp = pd.concat(val[21:28],axis=1)
zon_list2 = ['강원도','강원도','수도권','수도권','경상도','경상도','전라도','전라도','충청도','충청도','제주도','제주도','세종시','세종시']
tlist = ['T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX','T_MIN','T_MAX']
m4temp.columns= ['M78_%s_%s'%(z,t) for z,t in zip(zon_list2,tlist)]
m4weather = m4temp.iloc[:,:-2]
m4weather.fillna(m4weather.mean(),inplace=True)
p4 = pd.DataFrame([m4weather.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm78 = pd.concat([m78,p4],axis=1)


m4dust = pd.concat(dval[21:28],axis=1)
m4dust.columns= ['M78_%s_%s'%(z,t) for z,t in zip(zon_list,m4dust.columns)]
m4dust = m4dust.iloc[:,:-1]
m4dust.fillna(m4dust.mean(),inplace=True)
p4 = pd.DataFrame([m4dust.iloc[0]]*len(m4))
p4 = p4.reset_index()
p4.drop(columns='index',inplace=True)
fm78 = pd.concat([fm78,p4],axis=1)

# %%
fm78.to_csv('./2개월모델/m78_2.csv',index=False,index_label= False)

# %%
m4px.drop(columns='m4px_mean',inplace=True)
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
m4.concat[[m4,m4weather]]
# Out:
#         CLAC3_NM  M4_F_TOT_SALES  M4_F_HITS_SEQ  M4_M_TOT_SALES  \
# 0           2단우산            44.0      89.320000             5.0
# 1           3단우산           253.0      81.565445            44.0
# 2  BB/파운데이션/컴팩트류          8402.0      65.852596           492.0
# 3          DIY가구             1.0      31.000000            57.0
# 4           DSLR            18.0      68.944444             8.0
#
#    M4_M_HITS_SEQ  M4_10_TOT_SALES  M4_10_HITS_SEQ  M4_20_TOT_SALES  \
# 0      95.333333              NaN             NaN              1.0
# 1      59.714286              NaN             NaN              9.0
# 2      62.953811             47.0       53.116279           1851.0
# 3      80.363636              NaN             NaN              NaN
# 4      51.875000              NaN             NaN              4.0
#
#    M4_20_HITS_SEQ  M4_30_TOT_SALES  M4_30_HITS_SEQ  M4_40_TOT_SALES  \
# 0      162.000000             20.0       76.000000             24.0
# ...

# %%
m4px = m4px.T.fillna(m4px.mean(axis=1)).T
#m5px.T.fillna(m5px.mean(axis=1)).T
#m45px.T.fillna(m45px.mean(axis=1)).T

# %%
data.fillna(0,inplace=True)
data.set_index('CLAC3_NM',inplace=True)

# %%
data.head()
# Out:
#                M4_F_TOT_SALES  M4_F_HITS_SEQ  M4_M_TOT_SALES  M4_M_HITS_SEQ  \
# CLAC3_NM
# 2단우산                     44.0      89.320000             5.0      95.333333
# 3단우산                    253.0      81.565445            44.0      59.714286
# BB/파운데이션/컴팩트류          8402.0      65.852596           492.0      62.953811
# DIY가구                     1.0      31.000000            57.0      80.363636
# DSLR                     18.0      68.944444             8.0      51.875000
#
#                M4_10_TOT_SALES  M4_10_HITS_SEQ  M4_20_TOT_SALES  \
# CLAC3_NM
# 2단우산                       0.0        0.000000              1.0
# 3단우산                       0.0        0.000000              9.0
# BB/파운데이션/컴팩트류             47.0       53.116279           1851.0
# DIY가구                      0.0        0.000000              0.0
# DSLR                       0.0        0.000000              4.0
#
#                M4_20_HITS_SEQ  M4_30_TOT_SALES  M4_30_HITS_SEQ  \
# CLAC3_NM
# ...
