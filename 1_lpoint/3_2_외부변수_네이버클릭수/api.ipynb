# %%
import pandas as pd
import time
ctg1 = pd.read_csv("./날씨, 미세먼지 크롤링/ctg1.csv")
ctg2 = pd.read_csv("./날씨, 미세먼지 크롤링/ctg2.csv")
ctg3 = pd.read_csv("./날씨, 미세먼지 크롤링/ctg3_2.csv")

# %%
import os
import sys
import urllib.request
#ejin
#client_id = 'gKQslZZXZip9yn30AyPs'
#client_secret = '5w9Tk4tad6'

client_id ='oopMKe92cjMfSsXlkui6'
client_secret = 'cW7WSKtG1i'

url = "https://openapi.naver.com/v1/datalab/shopping/categories"

# %%
ctg3[ctg3['ctg3']=='곤충학습']
# Out:
# Empty DataFrame
# Columns: [ctg3, id, dict_list]
# Index: []

# %%
nn={
  "startDate": "2017-08-01",
  "endDate": "2017-09-30",
  "timeUnit": "month",
  "results":{'a':0}}

# %%
nn['results']
# Out:
# {'a': 0}

# %% [markdown]
# # CTG1의 전체 연령, 성별, 기기

# %%
dict_list=[]
for idx in range(len(ctg1)):
    name = ctg1.iloc[idx]['ctg1']
    param = ctg1.iloc[idx]['id']
    print(name,param)
    
    body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2019-01-08\",\"timeUnit\":\"date\",\"category\":[{\"name\":\"%s\",\"param\":[\"%s\"]}]}"%(name,param);
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    
    if(rescode==200):
        retData = response.read().decode('utf-8')
        jsonSearch = json.loads(str(retData))
        
    else:
        print("Error Code:" + rescode)
        
    dict_list.append(jsonSearch['results'][0]['data'])

    
ctg1['dict_list'] = dict_list
# Out:
# 패션의류 50000000
# 패션잡화 50000001
# 화장품/미용 50000002
# 디지털/가전 50000003
# 가구/인테리어 50000004
# 출산/육아 50000005
# 식품 50000006
# 스포츠/레저 50000007
# 생활/건강 50000008
# 여행/문화 50000009
# 면세점 50000010

# %%
ctg1.to_csv('ctg1_dict.csv',index=False,index_label=False)

# %%
test = pd.read_csv('ctg1_dict.csv')

# %% [markdown]
# ## - CTG1의 기기

# %% [markdown]
# ## - CTG1의 연령

# %%
df
# Out:
#       2017-08-01  2017-08-02  2017-08-03  2017-08-04  2017-08-05  2017-08-06  \
# 패션의류     31.1224     31.3456    29.77756    26.88864    27.15556    31.99622
#
#       2017-08-07  2017-08-08  2017-08-09  2017-08-10     ...      2018-12-29  \
# 패션의류    32.47356    32.31096    31.70592    29.69727     ...        52.18407
#
#       2018-12-30  2018-12-31  2019-01-01  2019-01-02  2019-01-03  2019-01-04  \
# 패션의류    57.80609    46.73973     56.4418    56.09072     53.4878    49.93926
#
#       2019-01-05  2019-01-06  2019-01-07
# 패션의류    53.95748    61.78211    57.66423
#
# [1 rows x 525 columns]

# %%
dict_list = ctg1.iloc[0]['dict_list']   
key_list = [j['period'] for j in dict_list]
val_list = [j['ratio'] for j in dict_list]
df = pd.DataFrame([val_list], columns=key_list,index=[ctg1.iloc[0]['ctg1']])

# %%
df.shape
# Out:
# (1, 525)

# %%
df=[]
for i in range(len(ctg1)):
    dict_list = ctg1.iloc[i]['dict_list']   
    key_list = [j['period'] for j in dict_list]
    val_list = [j['ratio'] for j in dict_list]
    df.append(pd.DataFrame([val_list], columns=key_list,index=[ctg1.iloc[i]['ctg1']]))
    
    
ctg1_df = df[0]
for i in range(1,len(df)):
    ctg1_df= pd.concat([ctg1_df,df[i]])

# %%
ctg1_df.to_csv('ctg1_df.csv',index=False,index_label=False)

# %%
df=[]
for i in range(len(ctg2)):
    dict_list = ctg2.iloc[i]['dict_list']   
    key_list = [j['period'] for j in dict_list]
    val_list = [j['ratio'] for j in dict_list]
    df.append(pd.DataFrame([val_list], columns=key_list,index=[ctg2.iloc[i]['ctg2']]))
    
    
ctg2_df = df[0]
for i in range(1,len(df)):
    ctg2_df= pd.concat([ctg2_df,df[i]])
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
ctg2_df.to_csv('ctg2_df.csv',index=False,index_label=False)

# %%
len(ctg1_df.columns)
# Out:
# 525

# %%
ctg3_df = ctg3_df.drop(columns='2019-01-08')
# Out:
# '2019-01-08'

# %%
ctg2_df[pd.isnull(ctg2_df['2019-01-07'])]
# Out:
# Empty DataFrame
# ...

# %%
ctg3.iloc[659]['dict_list']
# Out:
# [[{'period': '2017-08-01', 'ratio': 42.66648},
#   {'period': '2017-08-02', 'ratio': 39.79781},
#   {'period': '2017-08-03', 'ratio': 38.64946},
#   {'period': '2017-08-04', 'ratio': 34.54819},
#   {'period': '2017-08-05', 'ratio': 35.29159},
#   {'period': '2017-08-06', 'ratio': 46.20466},
#   {'period': '2017-08-07', 'ratio': 54.59785},
#   {'period': '2017-08-08', 'ratio': 48.61369},
#   {'period': '2017-08-09', 'ratio': 46.70125},
#   {'period': '2017-08-10', 'ratio': 43.04927},
#   {'period': '2017-08-11', 'ratio': 39.61159},
#   {'period': '2017-08-12', 'ratio': 39.21255},
#   {'period': '2017-08-13', 'ratio': 48.48659},
#   {'period': '2017-08-14', 'ratio': 49.44577},
#   {'period': '2017-08-15', 'ratio': 58.39762},
#   {'period': '2017-08-16', 'ratio': 53.41107},
#   {'period': '2017-08-17', 'ratio': 48.9817},
#   {'period': '2017-08-18', 'ratio': 43.59463},
#   {'period': '2017-08-19', 'ratio': 44.98832},
#   {'period': '2017-08-20', 'ratio': 58.50699},
# ...

# %%
ctg3.iloc[659]['dict_list'] = ctg3.iloc[659]['dict_list'][0]
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg3
# Out:
#              ctg3        id                                          dict_list
# 0          니트/스웨터  50000805  [{'period': '2017-08-01', 'ratio': 7.72701}, {...
# 1             카디건  50000806  [{'period': '2017-08-01', 'ratio': 37.92902}, ...
# 2             원피스  50000807  [{'period': '2017-08-01', 'ratio': 55.59109}, ...
# 3             티셔츠  50000803  [{'period': '2017-08-01', 'ratio': 55.34404}, ...
# 4         블라우스/셔츠  50000804  [{'period': '2017-08-01', 'ratio': 52.95059}, ...
# 5              점퍼  50000814  [{'period': '2017-08-01', 'ratio': 1.97957}, {...
# 6              재킷  50000815  [{'period': '2017-08-01', 'ratio': 8.45726}, {...
# 7              코트  50000813  [{'period': '2017-08-01', 'ratio': 4.75892}, {...
# 8             청바지  50000809  [{'period': '2017-08-01', 'ratio': 46.24996}, ...
# 9             스커트  50000808  [{'period': '2017-08-01', 'ratio': 53.14616}, ...
# 10            레깅스  50000812  [{'period': '2017-08-01', 'ratio': 20.98725}, ...
# ...

# %%
df=[]
for i in range(len(ctg3)):
    try:
        dict_list = ctg3.iloc[i]['dict_list']   
        key_list = [j['period'] for j in dict_list]
        val_list = [j['ratio'] for j in dict_list]
        df.append(pd.DataFrame([val_list], columns=key_list,index=[ctg3.iloc[i]['ctg3']]))
    except:
        print(i)
    
    
ctg3_df = df[0]
for i in range(1,len(df)):
    ctg3_df= pd.concat([ctg3_df,df[i]])
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
ctg3_df = ctg3_df.drop(columns='2019-01-08')

# %%
ctg3_df
# Out:
#              2017-08-01  2017-08-02  2017-08-03  2017-08-04  2017-08-05  \
# 니트/스웨터          7.72701     7.81005     7.42154     6.74788     5.93966
# 카디건            37.92902    37.71168    35.69447    30.06056    29.71190
# 원피스            55.59109    55.95007    54.10285    48.72020    51.55393
# 티셔츠            55.34404    56.47626    52.10813    47.52550    46.32492
# 블라우스/셔츠        52.95059    52.75081    49.07632    44.59736    46.56746
# 점퍼              1.97957     2.06844     2.10994     1.98889     1.96095
# 재킷              8.45726     8.51067     8.65961     8.11274     7.96505
# 코트              4.75892     4.73448     4.73714     4.83726     5.15706
# 청바지            46.24996    46.78199    43.35914    40.27947    37.77781
# 스커트            53.14616    54.40267    52.59175    45.19152    45.35226
# 레깅스            20.98725    21.72225    20.25225    17.29109    17.28504
# 바지             59.41725    60.03243    56.35020    50.86749    48.66447
# ...

# %%
idlist = ctg1['id']

# %%
[idlist]
# Out:
# [0     50000000
#  1     50000001
#  2     50000002
#  3     50000003
#  4     50000004
#  5     50000005
#  6     50000006
#  7     50000007
#  8     50000008
#  9     50000009
#  10    50000010
#  Name: id, dtype: int64]

# %%
ctg1_df['id'] = list(idlist)

# %%
idlist = ctg2['id']
ctg2_df['id'] = list(idlist)

# %%
idlist = ctg3['id']
ctg3_df['id'] = list(idlist)

# %%
ctg1_df.to_csv('ctg1_df.csv',index_label=False)
ctg1_df.to_csv('ctg1_df_lb.csv')

# %%
ctg2_df.to_csv('ctg2_df.csv',index_label=False)
ctg2_df.to_csv('ctg2_df_lb.csv')

# %%
ctg3_df.to_csv('ctg3_df.csv',index_label=False)
ctg3_df.to_csv('ctg3_df_lb.csv')

# %%
ctg3_df.head()
# Out:
#          2017-08-01  2017-08-02  2017-08-03  2017-08-04  2017-08-05  \
# 니트/스웨터      7.72701     7.81005     7.42154     6.74788     5.93966
# 카디건        37.92902    37.71168    35.69447    30.06056    29.71190
# 원피스        55.59109    55.95007    54.10285    48.72020    51.55393
# 티셔츠        55.34404    56.47626    52.10813    47.52550    46.32492
# 블라우스/셔츠    52.95059    52.75081    49.07632    44.59736    46.56746
#
#          2017-08-06  2017-08-07  2017-08-08  2017-08-09  2017-08-10  \
# 니트/스웨터      7.08911     7.55670     7.76944     8.02006     7.65549
# 카디건        36.05784    36.69289    34.34344    34.67172    31.79024
# 원피스        58.04430    57.80565    57.55489    56.76123    50.98988
# 티셔츠        52.27826    54.52548    54.42971    53.45901    48.96250
# 블라우스/셔츠    53.10187    50.24809    51.10444    50.51658    47.56281
#
#             ...      2018-12-30  2018-12-31  2019-01-01  2019-01-02  \
# 니트/스웨터      ...        73.21332    56.95440    70.41653    70.64018
# ...

# %%
ctg1_df.shape
# Out:
# (11, 525)

# %%
ctg2_df.shape
# Out:
# (205, 525)

# %%
ctg3_df.shape
# Out:
# (1814, 525)

# %% [markdown]
# # CTG2의 전체 연령, 성별, 기기

# %%
len(ctg2)
# Out:
# 205

# %%
dict_list=[]
for idx in range(125):
    name = ctg2.iloc[idx]['ctg2']
    param = ctg2.iloc[idx]['id']
    print(name,param)
    
    body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2019-01-08\",\"timeUnit\":\"date\",\"category\":[{\"name\":\"%s\",\"param\":[\"%s\"]}]}"%(name,param);
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    
    if(rescode==200):
        retData = response.read().decode('utf-8')
        jsonSearch = json.loads(str(retData))
        
    else:
        print("Error Code:" + rescode)
        
    dict_list.append(jsonSearch['results'][0]['data'])

    
#ctg2['dict_list'] = dict_list
# Out:
# 여성의류 50000167
# 여성언더웨어/잠옷 50000168
# 남성의류 50000169
# 남성언더웨어/잠옷 50000170
# 아동의류 50000171
# 아동언더웨어/잠옷 50000172
# 여성신발 50000173
# 남성신발 50000174
# 지갑 50000179
# 여행용가방/소품 50000178
# 신발용품 50000175
# 여성가방 50000176
# 남성가방 50000177
# 헤어액세서리 50000184
# 모자 50000181
# 패션소품 50000185
# 주얼리 50000189
# 순금 50000188
# 장갑 50000182
# 벨트 50000180
# 베이비주얼리 50000187
# 양말 50000166
# 선글라스/안경테 50000183
# 시계 50000186
# 스킨케어 50000190
# 선케어 50000191
# 클렌징 50000192
# 베이스메이크업 50000194
# 색조메이크업 50000195
# 뷰티소품 50000201
# 마스크/팩 50000193
# 네일케어 50000196
# 향수 50000200
# 바디케어 50000197
# 헤어케어 50000198
# 헤어스타일링 50000199
# 남성화장품 50000202
# 휴대폰 50000204
# 휴대폰 액세서리 50000205
# 카메라/캠코더용품 50000206
# 광학기기/용품 50000207
# 영상가전 50000208
# 계절가전 50000212
# 음향가전 50000209
# 생활가전 50000210
# 이미용가전 50000211
# 자동차기기 50000214
# PC 50000089
# 노트북 50000151
# PC부품 50000097
# PC액세서리 50000090
# 태블릿PC 50000152
# 모니터 50000153
# 모니터주변기기 50000093
# 태블릿PC액세서리 50000092
# 노트북액세서리 50000091
# 주방가전 50000213
# 멀티미디어장비 50000095
# 소프트웨어 50000099
# ...

# %%
ctg2.iloc[125:]['dict_list']=dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg2['dict_list']=[None for i in range(len(ctg2))]

# %%
ctg2['dict_list'][125:]=dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg2['dict_list'][:125]=dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg2[pd.isnull(ctg2['dict_list'])]
# Out:
# Empty DataFrame
# Columns: [ctg2, id, dict_list]
# Index: []

# %%
ctg2.to_csv('ctg2_dict.csv',index=False,index_label=False)

# %% [markdown]
# # CTG3의 전체 연령,성별,기기

# %%
len(ctg3)
# Out:
# 1814

# %%
dict_list=[]
for idx in range(1500,len(ctg3)):
    time.sleep(.5)
    
    name = ctg3.iloc[idx]['ctg3']
    param = ctg3.iloc[idx]['id']
    print(name,param)
    
    body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2019-01-08\",\"timeUnit\":\"date\",\"category\":[{\"name\":\"%s\",\"param\":[\"%s\"]}]}"%(name,param);
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    request.add_header("Content-Type","application/json")
    response = urllib.request.urlopen(request, data=body.encode("utf-8"))
    rescode = response.getcode()
    
    if(rescode==200):
        retData = response.read().decode('utf-8')
        jsonSearch = json.loads(str(retData))
        
    else:
        print("Error Code:" + rescode)
        
    dict_list.append(jsonSearch['results'][0]['data'])
# Out:
# 시트커버 50000638
# 편의용품 50000940
# 오일관리 50000941
# 익스테리어용품 50000942
# 인테리어용품 50000943
# 전기용품 50000944
# 수납용품 50000945
# 휴대폰용품 50000946
# 스노우체인 50000424
# 타이어/휠 50000947
# 튜닝용품 50000948
# 차량용케이블 50000423
# 피아노 50000959
# 기타(guitar) 50000868
# 건반악기 50000869
# 현악기 50000870
# 관악기 50000871
# 타악기 50000872
# 국악기 50000873
# 음향기자재 50000874
# 기타악기 50000875
# 영화 50000879
# 드라마 50000880
# 애니메이션 50000236
# 뮤직비디오 50000237
# 취미/스포츠 50000238
# 종교 50000239
# 교육 50000240
# 교양/다큐멘터리 50000241
# 유아/어린이 50000242
# 국내앨범 50000234
# 해외앨범 50000235
# 강아지 사료 50006630
# 강아지 간식 50006636
# 강아지 배변용품 50006646
# 강아지 건강/관리용품 50006654
# 강아지 미용/목욕 50006662
# 강아지 계단/스텝 50006672
# 강아지 장난감/훈련 50006673
# 고양이 사료 50006678
# 고양이 간식 50006684
# 고양이 배변용품 50006694
# 고양이 건강/관리용품 50006704
# 고양이 미용/목욕 50006708
# 고양이 캣타워 50006717
# 고양이 장난감 50006718
# 쿠션/하우스 50006724
# 패션용품 50006728
# 식기/급수기 50006734
# 캐리어/유모차 50006740
# 안전문/울타리 50006744
# 야외용품 50006747
# 햄스터용품 50000229
# 고슴도치용품 50000230
# 토끼용품 50000231
# 조류용품 50000232
# ...

# %%
len(dict_list)
# Out:
# 314

# %%
len(ctg3['dict_list'][1500:])
# Out:
# 314

# %%
ctg3['dict_list'][1500:]= dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg3.iloc[1500:]
# Out:
#              ctg3        id                                          dict_list
# 1500         시트커버  50000638  [{'period': '2017-08-01', 'ratio': 51.41068}, ...
# 1501         편의용품  50000940  [{'period': '2017-08-01', 'ratio': 14.60974}, ...
# 1502         오일관리  50000941  [{'period': '2017-08-01', 'ratio': 58.9088}, {...
# 1503      익스테리어용품  50000942  [{'period': '2017-08-01', 'ratio': 69.48223}, ...
# 1504       인테리어용품  50000943  [{'period': '2017-08-01', 'ratio': 41.21521}, ...
# 1505         전기용품  50000944  [{'period': '2017-08-01', 'ratio': 72.44465}, ...
# 1506         수납용품  50000945  [{'period': '2017-08-01', 'ratio': 54.11487}, ...
# 1507        휴대폰용품  50000946  [{'period': '2017-08-01', 'ratio': 44.43206}, ...
# 1508        스노우체인  50000424  [{'period': '2017-08-01', 'ratio': 0.4665}, {'...
# 1509        타이어/휠  50000947  [{'period': '2017-08-01', 'ratio': 59.53295}, ...
# 1510         튜닝용품  50000948  [{'period': '2017-08-01', 'ratio': 74.60285}, ...
# ...

# %%
ctg3['dict_list'].iloc[659]
# Out:
# [[{'period': '2017-08-01', 'ratio': 42.66648},
#   {'period': '2017-08-02', 'ratio': 39.79781},
#   {'period': '2017-08-03', 'ratio': 38.64946},
#   {'period': '2017-08-04', 'ratio': 34.54819},
#   {'period': '2017-08-05', 'ratio': 35.29159},
#   {'period': '2017-08-06', 'ratio': 46.20466},
#   {'period': '2017-08-07', 'ratio': 54.59785},
#   {'period': '2017-08-08', 'ratio': 48.61369},
#   {'period': '2017-08-09', 'ratio': 46.70125},
#   {'period': '2017-08-10', 'ratio': 43.04927},
#   {'period': '2017-08-11', 'ratio': 39.61159},
#   {'period': '2017-08-12', 'ratio': 39.21255},
#   {'period': '2017-08-13', 'ratio': 48.48659},
#   {'period': '2017-08-14', 'ratio': 49.44577},
#   {'period': '2017-08-15', 'ratio': 58.39762},
#   {'period': '2017-08-16', 'ratio': 53.41107},
#   {'period': '2017-08-17', 'ratio': 48.9817},
#   {'period': '2017-08-18', 'ratio': 43.59463},
#   {'period': '2017-08-19', 'ratio': 44.98832},
#   {'period': '2017-08-20', 'ratio': 58.50699},
# ...

# %%
ctg3['dict_list'][659]= dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg3['dict_list'][660:1000]= dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ctg3['dict_list']=[None for i in range(len(ctg3))]   
ctg3['dict_list'][:500] = dict_list
# Out:
# /Users/YiYoung/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ctg3.to_csv('ctg3_finaldict.csv',index=False,index_label=False)

# %%
ctg2
# Out:
#            ctg2        id                                          dict_list
# 0          여성의류  50000167  [{'period': '2017-08-01', 'ratio': 37.01739}, ...
# 1     여성언더웨어/잠옷  50000168  [{'period': '2017-08-01', 'ratio': 61.75268}, ...
# 2          남성의류  50000169  [{'period': '2017-08-01', 'ratio': 22.4637}, {...
# 3     남성언더웨어/잠옷  50000170  [{'period': '2017-08-01', 'ratio': 35.00446}, ...
# 4          아동의류  50000171  [{'period': '2017-08-01', 'ratio': 17.89299}, ...
# 5     아동언더웨어/잠옷  50000172  [{'period': '2017-08-01', 'ratio': 19.74449}, ...
# 6          여성신발  50000173  [{'period': '2017-08-01', 'ratio': 44.96312}, ...
# 7          남성신발  50000174  [{'period': '2017-08-01', 'ratio': 46.69236}, ...
# 8            지갑  50000179  [{'period': '2017-08-01', 'ratio': 41.48719}, ...
# 9      여행용가방/소품  50000178  [{'period': '2017-08-01', 'ratio': 82.92463}, ...
# 10         신발용품  50000175  [{'period': '2017-08-01', 'ratio': 32.91156}, ...
# ...

# %%
test= pd.read_csv('ctg3_dict.csv')

# %%
body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2017-09-30\",\"timeUnit\":\"date\",\"category\":[{\"name\":\"패션의류\",\"param\":[\"50000000\"]}],\"device\":\"\",\"ages\":[\"20\",\"30\"],\"gender\":\"f\"}";

# %%
ctg1.head()
# Out:
#       ctg1        id
# 0     패션의류  50000000
# 1     패션잡화  50000001
# 2   화장품/미용  50000002
# 3   디지털/가전  50000003
# 4  가구/인테리어  50000004

# %%
#body = "{'startDate':'2017-08-01','endDate':'2017-09-30','timeUnit':'date','category':[{'name':'패션의류','param':['50000000']}],'device':'pc','ages':['20','30'],'gender':'f'}"
body = "{\"startDate\":\"2017-08-01\",\"endDate\":\"2017-09-30\",\"timeUnit\":\"date\",\"category\":[{\"name\":\"패션의류\",\"param\":[\"50000000\"]}],\"device\":\"\",\"ages\":[\"20\",\"30\"],\"gender\":\"f\"}";

#dict('startDate':'2017-08-01','endDate':'2017-09-30','timeUnit':'date','category':[{'name':'패션의류','param':['50000000']}],'device':'pc','ages':['20','30'],'gender':'f')

#,\"device\":\"%s\",\"ages\":[\"%d\",\"30\"],\"gender\":\"f\"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()


if(rescode==200):
    retData = response.read().decode('utf-8')
    
    jsonSearch = json.loads(str(retData))
    print(jsonSearch)
    
    newctg1 = jsonSearch['results'][0]['data']
    
    
    
else:
    print("Error Code:" + rescode)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-76-585fc3b8c29a> in <module>
#      13 request.add_header("X-Naver-Client-Secret",client_secret)
#      14 request.add_header("Content-Type","application/json")
# ---> 15 response = urllib.request.urlopen(request, data=body.encode("utf-8"))
#      16 rescode = response.getcode()
#      17
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# ...

# %%
newctg1
# Out:
# [{'period': '2017-08-01', 'ratio': 66.9209},
#  {'period': '2017-08-02', 'ratio': 67.40083},
#  {'period': '2017-08-03', 'ratio': 64.02915},
#  {'period': '2017-08-04', 'ratio': 57.81726},
#  {'period': '2017-08-05', 'ratio': 58.3912},
#  {'period': '2017-08-06', 'ratio': 68.79982},
#  {'period': '2017-08-07', 'ratio': 69.82622},
#  {'period': '2017-08-08', 'ratio': 69.4766},
#  {'period': '2017-08-09', 'ratio': 68.17562},
#  {'period': '2017-08-10', 'ratio': 63.85652},
#  {'period': '2017-08-11', 'ratio': 56.84957},
#  {'period': '2017-08-12', 'ratio': 54.20953},
#  {'period': '2017-08-13', 'ratio': 64.79674},
#  {'period': '2017-08-14', 'ratio': 66.13232},
#  {'period': '2017-08-15', 'ratio': 74.83566},
#  {'period': '2017-08-16', 'ratio': 69.33802},
#  {'period': '2017-08-17', 'ratio': 68.70453},
#  {'period': '2017-08-18', 'ratio': 62.62316},
#  {'period': '2017-08-19', 'ratio': 62.34396},
#  {'period': '2017-08-20', 'ratio': 76.77076},
# ...
